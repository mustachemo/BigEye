# %%
from etl.extract import extract_data_from_bigquery
import pandas as pd

df = extract_data_from_bigquery()

# set setting to show all columns
pd.set_option('display.max_columns', None)
# Out:
# INFO - Query returned 10000 rows and 61 columns

# %%
df.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0     1172853055  20240430     202404  2024     2024.3288     USAEDU
# 1     1172852890  20240430     202404  2024     2024.3288        USA
# 2     1172852895  20240430     202404  2024     2024.3288        USA
# 3     1172852896  20240430     202404  2024     2024.3288        USA
# 4     1172852906  20240430     202404  2024     2024.3288        USA
#
#       Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0  UNITED STATES               USA                 None             None
# 1  UNITED STATES               USA                 None             None
# 2  UNITED STATES               USA                 None             None
# 3  UNITED STATES               USA                 None             None
# 4  UNITED STATES               USA                 None             None
#
#   Actor1Religion1Code Actor1Religion2Code Actor1Type1Code Actor1Type2Code  \
# 0                None                None             EDU            None
# 1                None                None            None            None
# 2                None                None            None            None
# 3                None                None            None            None
# 4                None                None            None            None
#
#   Actor1Type3Code Actor2Code Actor2Name Actor2CountryCode  \
# 0            None       None       None              None
# 1            None       None       None              None
# 2            None       None       None              None
# 3            None       None       None              None
# 4            None       None       None              None
#
#   Actor2KnownGroupCode Actor2EthnicCode Actor2Religion1Code  \
# 0                 None             None                None
# 1                 None             None                None
# 2                 None             None                None
# 3                 None             None                None
# 4                 None             None                None
#
#   Actor2Religion2Code Actor2Type1Code Actor2Type2Code Actor2Type3Code  \
# 0                None            None            None            None
# 1                None            None            None            None
# 2                None            None            None            None
# 3                None            None            None            None
# 4                None            None            None            None
#
#    IsRootEvent EventCode EventBaseCode EventRootCode  QuadClass  \
# 0            0       042           042            04          1
# 1            1       014           014            01          1
# 2            0       040           040            04          1
# 3            1       040           040            04          1
# 4            1       051           051            05          1
#
#    GoldsteinScale  NumMentions  NumSources  NumArticles   AvgTone  \
# 0             1.9            2           1            2 -5.253067
# 1             0.0            8           1            8  1.632653
# 2             1.0            2           1            2 -6.756757
# 3             1.0            1           1            1  1.223242
# 4             3.4            2           1            2  1.223242
#
#    Actor1Geo_Type                               Actor1Geo_FullName  \
# 0               2                        Washington, United States
# 1               3         Ward County, North Dakota, United States
# 2               3                Lucas County, Ohio, United States
# 3               3  Grove City College, Pennsylvania, United States
# 4               3  Grove City College, Pennsylvania, United States
#
#   Actor1Geo_CountryCode Actor1Geo_ADM1Code Actor1Geo_ADM2Code  Actor1Geo_Lat  \
# 0                    US               USWA               None        47.3917
# 1                    US               USND              ND101        48.2167
# 2                    US               USOH              OH095        41.6501
# 3                    US               USPA              PA085        41.1556
# 4                    US               USPA              PA085        41.1556
#
#    Actor1Geo_Long Actor1Geo_FeatureID  Actor2Geo_Type Actor2Geo_FullName  \
# 0       -121.5710                  WA               0               None
# 1       -101.4590             1034231               0               None
# 2        -83.6666             1074060               0               None
# 3        -80.0792             1176274               0               None
# 4        -80.0792             1176274               0               None
#
#   Actor2Geo_CountryCode Actor2Geo_ADM1Code Actor2Geo_ADM2Code  Actor2Geo_Lat  \
# 0                  None               None               None            NaN
# 1                  None               None               None            NaN
# 2                  None               None               None            NaN
# 3                  None               None               None            NaN
# 4                  None               None               None            NaN
#
#    Actor2Geo_Long Actor2Geo_FeatureID  ActionGeo_Type  \
# 0             NaN                None               4
# 1             NaN                None               3
# 2             NaN                None               3
# 3             NaN                None               3
# 4             NaN                None               3
#
#                                 ActionGeo_FullName ActionGeo_CountryCode  \
# 0                   Gaza, Israel (general), Israel                    IS
# 1         Ward County, North Dakota, United States                    US
# 2                Lucas County, Ohio, United States                    US
# 3  Grove City College, Pennsylvania, United States                    US
# 4  Grove City College, Pennsylvania, United States                    US
#
#   ActionGeo_ADM1Code ActionGeo_ADM2Code  ActionGeo_Lat  ActionGeo_Long  \
# 0               IS00              18315        31.4167         34.3333
# 1               USND               None        48.2167       -101.4590
# 2               USOH               None        41.6501        -83.6666
# 3               USPA               None        41.1556        -80.0792
# 4               USPA               None        41.1556        -80.0792
#
#   ActionGeo_FeatureID       DATEADDED  \
# 0             -797156  20240430030000
# 1             1034231  20240430030000
# 2             1074060  20240430030000
# 3             1176274  20240430030000
# 4             1176274  20240430030000
#
#                                            SOURCEURL
# 0  http://www.middletownpress.com/news/article/de...
# 1  https://www.kxnet.com/news/top-stories/north-d...
# 2  https://www.wtol.com/article/news/health/tick-...
# 3  https://natlawreview.com/author/donald-c-blued...
# 4  https://natlawreview.com/author/donald-c-blued...

# %%
# save 5 rows to csv
df.head().to_csv('data/5_rows.csv', index=False)
