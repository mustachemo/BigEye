# %%
from etl.extract import extract_data_from_bigquery
import pandas as pd

df = extract_data_from_bigquery()

# set setting to show all columns
pd.set_option('display.max_columns', None)
# Out:
# INFO - Query returned 1000 rows and 9 columns

# %%
df.head(100)
# Out:
#     GLOBALEVENTID   SQLDATE     Actor1Name     Actor2Name EventCode  \
# 0      1172856868  20240430    PALESTINIAN         ISRAEL       141
# 1      1172856843  20240430          NIGER       COMMANDO       111
# 2      1172856586  20240430     UNIVERSITY     CALIFORNIA       160
# 3      1172856756  20240430         ISRAEL           A US      1822
# 4      1172856872  20240430           GAZA  UNITED STATES       190
# ..            ...       ...            ...            ...       ...
# 95     1172852343  20240430         SCHOOL     LEGISLATOR       071
# 96     1172852352  20240430         SCHOOL  UNITED STATES       010
# 97     1172852188  20240430      CHRISTIAN           IOWA       046
# 98     1172852969  20240430  UNITED STATES          PUPIL       010
# 99     1172852977  20240430  UNITED STATES         SCHOOL       071
#
#                ActionGeo_FullName ActionGeo_CountryCode ActionGeo_ADM1Code  \
# 0       California, United States                    US               USCA
# 1                   United States                    US                 US
# 2       California, United States                    US               USCA
# 3       California, United States                    US               USCA
# 4       California, United States                    US               USCA
# ..                            ...                   ...                ...
# 95  Camanche, Iowa, United States                    US               USIA
# 96  Camanche, Iowa, United States                    US               USIA
# 97        Missouri, United States                    US               USMO
# 98  Camanche, Iowa, United States                    US               USIA
# 99  Camanche, Iowa, United States                    US               USIA
#
#                                             SOURCEURL
# 0   http://arabic.news.cn/20240430/a9473caf3bb8486...
# 1   https://malijet.com/actualte_dans_les_regions_...
# 2   https://lajornadasanluis.com.mx/internacional/...
# 3                    https://jang.com.pk/news/1345522
# 4   https://www.sakshi.com/telugu-news/internation...
# ..                                                ...
# 95  https://www.clintonherald.com/news/retiring-su...
# 96  https://www.clintonherald.com/news/retiring-su...
# 97  https://siouxcityjournal.com/news/state-region...
# 98  https://www.clintonherald.com/news/retiring-su...
# 99  https://www.clintonherald.com/news/retiring-su...
#
# [100 rows x 9 columns]

# %%
# save 5 rows to csv
df.head().to_csv('data/5_rows.csv', index=False)
